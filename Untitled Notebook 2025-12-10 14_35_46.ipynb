# %%
# %sql
use catalog new_catalog

# %%
# %sql
create table test (
  sno int,
  sname varchar(100)
)

# %%
# %sql
insert into test
values (1,'sunny'),
(2,'Rockey');
insert into test
values (3,'Raj'),
(4,'danny');
insert into test 
values (5,'surya'),
(6,'sandy');
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>2</td><td>2</td></tr></tbody></table></div>

# %%
# %sql
select * from new_catalog.default.test
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>sno</th><th>sname</th></tr></thead><tbody><tr><td>1</td><td>sunny</td></tr><tr><td>2</td><td>Rockey</td></tr><tr><td>5</td><td>surya</td></tr><tr><td>6</td><td>sandy</td></tr><tr><td>3</td><td>Raj</td></tr><tr><td>4</td><td>danny</td></tr></tbody></table></div>

# %% [markdown]
# ##Need to display version history of table
#
# * We can Display history of the table
# * We can See all Operation of the current table

# %%
# %sql

describe history new_catalog.default.test
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# ##Need to Display along with external path.
#
# * we can Display external location of table
# * we can find numbers of current table
# * we can see table format of current table

# %%
# %sql

describe detail new_catalog.default.test
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# ##file exploration
#
# You can explore the file using magic command
#
# Syntax -> %fs ls 'external path'
#
# expmple -> %fs ls 'dbfs:/user/Hive/warehouse/test'

# %% [markdown]
# ##Update test table

# %%
# %sql
update test set sno = sno + 100
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th></tr></thead><tbody><tr><td>6</td></tr></tbody></table></div>

# %% [markdown]
# ## Query table

# %%
# %sql
select * from new_catalog.default.test
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>sno</th><th>sname</th></tr></thead><tbody><tr><td>101</td><td>sunny</td></tr><tr><td>102</td><td>Rockey</td></tr><tr><td>103</td><td>Raj</td></tr><tr><td>104</td><td>danny</td></tr><tr><td>105</td><td>surya</td></tr><tr><td>106</td><td>sandy</td></tr></tbody></table></div>

# %% [markdown]
# ## Explore File
#
# * We can explore file after updation.
# * we can get 6 more file after updating result.
#
# example -> %fs ls 'dbfs/users/Hive/warehouse/test'

# %% [markdown]
# ##Number 1 file is valid

# %%
# %sql
describe detail new_catalog.default.test
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# ##Need to display version of file
#
# We can See Version of file of current table by using below syntax
#
# describe History table_name

# %%
# %sql
describe history new_catalog.default.test
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# ##Trasaction log
#
# * this trasaction log are located under delta_log
# * You can see each trasaction of Delta table
# * each transaction create a new json file

# %% [markdown]
# **We can explore the folder by using below code **
#
# %fs ls 'dbfs/users/hive/warehouse/test/delta_log'

# %% [markdown]
# we can see breif description of update file
#
# %fs head 'dbfs/users/hive/warehouse/test/delta_log/0000000005.json'
